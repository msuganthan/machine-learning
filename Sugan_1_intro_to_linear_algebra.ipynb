# %% [markdown]
# <a href="https://colab.research.google.com/github/msuganthan/machine-learning/blob/main/Sugan_1_intro_to_linear_algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0, 40, 1000)

# %%
d_r = 2.5 * t
d_s = 3 * (t - 5)

# %%
fig, ax = plt.subplots()
plt.title('A bank Robber caught')
plt.xlabel('time (in minutes)')
plt.ylabel('distance (in km)')

ax.set_xlim([0, 40])
ax.set_ylim([0, 100])
ax.plot(t, d_r, c = 'green')
ax.plot(t, d_s, c = 'brown')

plt.axvline(x = 30, color = 'purple', linestyle = '--')
plt.axhline(y = 75, color = 'purple', linestyle = '--')

# %% [markdown]
# Scalars in Base Python

# %%
x = 25
x
# Out:
# 25

# %%
type(x)
# Out:
# int

# %%
y = 3

# %%
py_sum = x + y
py_sum
# Out:
# 28

# %%
x_float = 25.0
float_sum = x_float + y
float_sum
# Out:
# 28.0

# %%
type(float_sum)
# Out:
# float

# %% [markdown]
# Scalars in Pytorch

# %%
import torch

# %%
x_pt = torch.tensor(25)
x_pt
# Out:
# tensor(25)

# %%
x_pt.shape
# Out:
# torch.Size([])

# %% [markdown]
# Scalars in TensorFlow

# %%
import tensorflow as tf

# %%
x_tf = tf.Variable(25, dtype=tf.int16)
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=int16, numpy=25>

# %%
x_tf.shape
# Out:
# TensorShape([])

# %%
y_tf = tf.Variable(3, dtype = tf.int16)

# %%
x_tf + y_tf
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
tf_sum = tf.add(x_tf, y_tf)
tf_sum
# Out:
# <tf.Tensor: shape=(), dtype=int16, numpy=28>

# %%
tf_float = tf.Variable(25., dtype=tf.float16)
tf_float
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float16, numpy=25.0>

# %% [markdown]
# Vectors in NumPy

# %%
x = np.array([25, 2, 5])
x
# Out:
# array([25,  2,  5])

# %%
len(x)
# Out:
# 3

# %%
x.shape
# Out:
# (3,)

# %%
type(x)
# Out:
# numpy.ndarray

# %% [markdown]
# Vector Transposition

# %%
x_t = x.T
x_t
# Out:
# array([25,  2,  5])

# %%
x_t.shape
# Out:
# (3,)

# %%
y = np.array([[25, 2, 5]])
y
# Out:
# array([[25,  2,  5]])

# %%
y.shape
# Out:
# (1, 3)

# %%
y_t = y.T
y_t
# Out:
# array([[25],
#        [ 2],
#        [ 5]])

# %%
y_t.shape
# Out:
# (3, 1)

# %%
y_t.T
# Out:
# array([[25,  2,  5]])

# %% [markdown]
# Zero Vectors
#
# Have no effect if added to another vector

# %%
z = np.zeros(3)
z
# Out:
# array([0., 0., 0.])

# %% [markdown]
# Vector in Pytorch and TensorFlow

# %%
x_pt = torch.tensor([25, 2, 5])
x_pt
# Out:
# tensor([25,  2,  5])

# %%
x_tf = tf.Variable([25, 2, 25])
x_tf
# Out:
# <tf.Variable 'Variable:0' shape=(3,) dtype=int32, numpy=array([25,  2, 25], dtype=int32)>

# %% [markdown]
# L2 Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)**(1/2)
# Out:
# 25.573423705088842

# %%
np.linalg.norm(x)
# Out:
# 25.573423705088842

# %% [markdown]
# L1 Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.abs(25) + np.abs(2) + np.abs(5)
# Out:
# 32

# %% [markdown]
# Squared L2 Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
(25**2 + 2**2 + 5**2)
# Out:
# 654

# %%
np.dot(x, x)
# Out:
# 654

# %% [markdown]
# Max Norm

# %%
x
# Out:
# array([25,  2,  5])

# %%
np.max([np.abs(25), np.abs(2), np.abs(5)])
# Out:
# 25

# %% [markdown]
# Orthogonal Vector

# %%
i = np.array([1, 0])
i
# Out:
# array([1, 0])

# %%
j = np.array([0, 1])
j
# Out:
# array([0, 1])

# %%
np.dot(i, j)
# Out:
# 0
